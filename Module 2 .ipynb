# %% [markdown]
# # Assignment 2

# %%
import pandas as pd

# TODO: Load up the 'tutorial.csv' dataset
data = pd.read_csv('tutorial.csv')

# %%
data
# Out:
#        col0      col1      col2      col3
# 0 -0.722876 -1.330682  1.309208  0.232378
# 1  1.160396 -0.730879  0.677368  1.044722
# 2 -1.062870 -0.503704 -0.238536 -1.417937
# 3  0.437078  0.362640 -0.111228 -1.649853

# %%
data.describe()
# Out:
#            col0      col1      col2      col3
# count  4.000000  4.000000  4.000000  4.000000
# mean  -0.047068 -0.550656  0.409203 -0.447672
# std    1.029715  0.701720  0.723956  1.300815
# min   -1.062870 -1.330682 -0.238536 -1.649853
# 25%   -0.807875 -0.880830 -0.143055 -1.475916
# 50%   -0.142899 -0.617291  0.283070 -0.592780
# 75%    0.617907 -0.287118  0.835328  0.435464
# max    1.160396  0.362640  1.309208  1.044722

# %%
data.loc[2:4,'col3']
# Out:
# 2   -1.417937
# 3   -1.649853
# Name: col3, dtype: float64

# %% [markdown]
# # Assignment3

# %%
import pandas as pd
data3 = pd.read_csv('servo.data',header=None)

# %%
data3.head()
# Out:
#    0  1  2  3         4
# 0  E  E  5  4  0.281251
# 1  B  D  6  5  0.506252
# 2  D  D  4  3  0.356251
# 3  B  A  3  2  5.500033
# 4  D  B  6  5  0.356251

# %%
data3.columns = ['motor', 'screw', 'pgain', 'vgain', 'class']
data3.head(n=5)
# Out:
#   motor screw  pgain  vgain     class
# 0     E     E      5      4  0.281251
# 1     B     D      6      5  0.506252
# 2     D     D      4      3  0.356251
# 3     B     A      3      2  5.500033
# 4     D     B      6      5  0.356251

# %%
data3[data3['vgain']==5]
# Out:
#     motor screw  pgain  vgain     class
# 1       B     D      6      5  0.506252
# 4       D     B      6      5  0.356251
# 8       C     A      6      5  0.768754
# 10      B     E      6      5  0.468752
# 22      B     C      6      5  0.468752
# 24      A     B      6      5  0.581253
# 25      E     C      6      5  0.393752
# 34      C     C      6      5  0.506252
# 38      C     B      6      5  0.543753
# 50      D     A      6      5  0.431252
# 70      B     A      6      5  0.806255
# 73      A     E      6      5  0.506252
# 81      A     C      6      5  0.506252
# 84      E     A      6      5  0.581253
# 95      A     D      6      5  0.506252
# 108     E     B      6      5  0.431252
# 112     C     D      6      5  0.468752
# 117     E     D      6      5  0.318751
# 132     E     E      6      5  0.281251
# 135     B     B      6      5  0.543753
# 161     C     E      6      5  0.468752
# 166     A     A      6      5  0.806255

# %%
data3[(data3['motor']=='E') & (data3['screw']=='E')].shape
# Out:
# (6, 5)

# %%
sol = data3[data3['pgain']==4]
sol.describe()
# Out:
#        pgain      vgain      class
# count   66.0  66.000000  66.000000
# mean     4.0   2.060606   0.673298
# std      0.0   0.820484   0.314105
# min      4.0   1.000000   0.131250
# 25%      4.0   1.000000   0.365627
# 50%      4.0   2.000000   0.712504
# 75%      4.0   3.000000   0.956256
# max      4.0   3.000000   1.218740

# %%
sol
# Out:
#     motor screw  pgain  vgain     class
# 2       D     D      4      3  0.356251
# 5       E     C      4      3  0.806255
# 9       D     A      4      1  1.031254
# 12      B     C      4      1  0.281251
# 19      C     E      4      2  0.206250
# 20      E     D      4      3  0.918755
# 21      A     D      4      3  1.106248
# 23      A     C      4      2  0.581253
# 27      A     E      4      2  0.468752
# 30      B     E      4      2  0.356251
# 32      C     E      4      1  0.543753
# 37      E     C      4      2  0.131250
# 39      C     D      4      1  0.206250
# 40      D     B      4      1  0.693754
# 41      C     B      4      3  0.881255
# 42      C     C      4      3  0.918755
# 43      B     D      4      1  0.243751
# 45      A     B      4      3  1.031254
# 46      B     A      4      1  0.806255
# 47      E     D      4      2  0.431252
# 54      B     B      4      2  0.731254
# 55      A     E      4      3  1.143746
# ...

# %% [markdown]
# # Assignment 4

# %%
url = 'http://www.espn.com/nhl/statistics/player/_/stat/points/sort/points/year/2015/seasontype/2'

# %%
import pandas as pd
html = pd.read_html(url,header=1)

# %%
df = html[0]

df.shape
# Out:
# (46, 17)

# %%
df.drop('RK',axis=1)
# Out:
#                     PLAYER  TEAM   GP    G    A  PTS  +/-  PIM  PTS/G  SOG  \
# 0           Jamie Benn, LW   DAL   82   35   52   87    1   64   1.06  253
# 1          John Tavares, C   NYI   82   38   48   86    5   46   1.05  278
# 2         Sidney Crosby, C   PIT   77   28   56   84    5   47   1.09  237
# 3        Alex Ovechkin, LW   WSH   81   53   28   81   10   58   1.00  395
# 4        Jakub Voracek, RW   PHI   82   22   59   81    1   78   0.99  221
# 5     Nicklas Backstrom, C   WSH   82   18   60   78    5   40   0.95  153
# 6          Tyler Seguin, C   DAL   71   37   40   77   -1   20   1.08  280
# 7          Jiri Hudler, LW   CGY   78   31   45   76   17   14   0.97  158
# 8         Daniel Sedin, LW   VAN   82   20   56   76    5   18   0.93  226
# 9   Vladimir Tarasenko, RW   STL   77   37   36   73   27   31   0.95  264
# 10                      PP    SH  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# ...

# %%
df_drop = df.dropna(axis=0,thresh=4).drop('RK',axis=1).reset_index()
df_drop = df_drop.drop('index',axis=1)
df_drop
# Out:
#                     PLAYER  TEAM  GP   G   A  PTS  +/-  PIM  PTS/G  SOG   PCT  \
# 0           Jamie Benn, LW   DAL  82  35  52   87    1   64   1.06  253  13.8
# 1          John Tavares, C   NYI  82  38  48   86    5   46   1.05  278  13.7
# 2         Sidney Crosby, C   PIT  77  28  56   84    5   47   1.09  237  11.8
# 3        Alex Ovechkin, LW   WSH  81  53  28   81   10   58   1.00  395  13.4
# 4        Jakub Voracek, RW   PHI  82  22  59   81    1   78   0.99  221  10.0
# 5     Nicklas Backstrom, C   WSH  82  18  60   78    5   40   0.95  153  11.8
# 6          Tyler Seguin, C   DAL  71  37  40   77   -1   20   1.08  280  13.2
# 7          Jiri Hudler, LW   CGY  78  31  45   76   17   14   0.97  158  19.6
# 8         Daniel Sedin, LW   VAN  82  20  56   76    5   18   0.93  226   8.9
# 9   Vladimir Tarasenko, RW   STL  77  37  36   73   27   31   0.95  264  14.0
# 10                  PLAYER  TEAM  GP   G   A  PTS  +/-  PIM  PTS/G  SOG   PCT
# ...

# %%
df_final = df_drop.drop(df_drop.index[[10,21,32]])

# %%
df_final.columns
# Out:
# Index(['PLAYER', 'TEAM', 'GP', 'G', 'A', 'PTS', '+/-', 'PIM', 'PTS/G', 'SOG',
#        'PCT', 'GWG', 'G.1', 'A.1', 'G.2', 'A.2'],
#       dtype='object')

# %%
df_final.describe()
# Out:
#                  PLAYER TEAM  GP   G   A PTS +/- PIM PTS/G  SOG   PCT GWG G.1  \
# count                40   40  40  40  40  40  40  40    40   40    40  40  40
# unique               40   21  12  20  23  18  26  28    27   39    36  10  15
# top     John Tavares, C   TB  82  28  40  64   5  36  0.84  237  13.2   5   6
# freq                  1    4  14   5   5   7   5   4     4    2     2   8   9
#
#        A.1 G.2 A.2
# count   40  40  40
# unique  20   5   4
# top     13   0   0
# freq     4  31  32

# %%
df_final.loc[15,'GP']+df_final.loc[16,'GP']
# Out:
# '7782'

# %%
df_final
# Out:
#                     PLAYER TEAM  GP   G   A PTS  +/- PIM PTS/G  SOG   PCT GWG  \
# 0        Connor McDavid, C  EDM  45  14  36  50   12  20  1.11  135  10.4   3
# 1         Patrick Kane, RW  CHI  46  14  33  47    7  24  1.02  160   8.8   4
# 2         Sidney Crosby, C  PIT  36  26  20  46    8  14  1.28  122  21.3   3
# 3         Evgeni Malkin, C  PIT  42  18  28  46    7  50  1.10  128  14.1   4
# 4   Vladimir Tarasenko, RW  STL  44  20  24  44   -7   8  1.00  147  13.6   4
# 5           Brent Burns, D   SJ  43  17  27  44   15  18  1.02  167  10.2   3
# 6       Artemi Panarin, LW  CHI  46  17  26  43   14  19  0.93  114  14.9   2
# 7        Brad Marchand, LW  BOS  46  17  26  43    9  42  0.93  134  12.7   4
# 8          Tyler Seguin, C  DAL  44  16  27  43  -10  14  0.98  156  10.3   1
# 9     Nicklas Backstrom, C  WSH  43  12  30  42   14  22  0.98   84  14.3   2
# 11        Cam Atkinson, RW  CBJ  42  21  20  41    1  12  0.98  124  16.9   4
# ...

# %%
df
# Out:
#      RK                  PLAYER  TEAM   GP    G    A  PTS  +/-  PIM  PTS/G  \
# 0     1       Connor McDavid, C   EDM   45   14   36   50   12   20   1.11
# 1     2        Patrick Kane, RW   CHI   46   14   33   47    7   24   1.02
# 2     3        Sidney Crosby, C   PIT   36   26   20   46    8   14   1.28
# 3   NaN        Evgeni Malkin, C   PIT   42   18   28   46    7   50   1.10
# 4     5  Vladimir Tarasenko, RW   STL   44   20   24   44   -7    8   1.00
# 5   NaN          Brent Burns, D    SJ   43   17   27   44   15   18   1.02
# 6     7      Artemi Panarin, LW   CHI   46   17   26   43   14   19   0.93
# 7   NaN       Brad Marchand, LW   BOS   46   17   26   43    9   42   0.93
# 8   NaN         Tyler Seguin, C   DAL   44   16   27   43  -10   14   0.98
# 9    10    Nicklas Backstrom, C   WSH   43   12   30   42   14   22   0.98
# 10  NaN                      PP    SH  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# ...

# %% [markdown]
# # Assignment 5

# %%
import pandas as pd
census = pd.read_csv('census.data',header=None)
census = census.drop(0,axis=1)
census.columns = ['education', 'age', 'capital-gain', 'race', 'capital-loss', 'hours-per-week', 'sex', 'classification']

# %%
census.describe()
# Out:
#                 age  capital-loss  hours-per-week
# count  29536.000000  29536.000000    29536.000000
# mean      38.506094     84.957408       40.243872
# std       13.811739    397.107750       12.326211
# min       17.000000      0.000000        1.000000
# 25%       27.000000      0.000000       40.000000
# 50%       37.000000      0.000000       40.000000
# 75%       48.000000      0.000000       45.000000
# max       90.000000   4356.000000       99.000000

# %%
census
# Out:
#           education  age capital-gain                race  capital-loss  \
# 0         Bachelors   39         2174               White             0
# 1         Bachelors   50            ?               White             0
# 2           HS-grad   38            ?               White             0
# 3              11th   53            ?               Black             0
# 4         Bachelors   28            0               Black             0
# 5           Masters   37            0               White             0
# 6               9th   49            0               Black             0
# 7           HS-grad   52            0               White             0
# 8           Masters   31        14084               White             0
# 9         Bachelors   42         5178               White             0
# 10     Some-college   37            0               Black             0
# 11        Bachelors   30            0  Asian-Pac-Islander             0
# ...
